# %%
try:
    file = open('data.csv','x')
    file.close()
except:
    print("The file is already there")
# Out:
# The file is already there

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#    Sn    Name  Age    Address       Phone
# 0   1     Ram   34  Kathmandu  9898667654
# 1   2   Shyam   56   Lalitpur  9808667654
# 2   3   Nabin   78  Bhaktapur  9856554543
# 3   4   Sabin   54       Bara  9867554543
# 4   5  Nirman   12       Bara  9808556543
# 5   6  Sabina   56  Kathmandu  9808667654

# %%
import pandas as pd
df = pd.read_csv('data.csv',usecols = ['Sn','Name','Phone'])
df
# Out:
#    Sn    Name       Phone
# 0   1     Ram  9898667654
# 1   2   Shyam  9808667654
# 2   3   Nabin  9856554543
# 3   4   Sabin  9867554543
# 4   5  Nirman  9808556543
# 5   6  Sabina  9808667654

# %%
df.head(3)
# Out:
#    Sn   Name  Age    Address       Phone
# 0   1    Ram   34  Kathmandu  9898667654
# 1   2  Shyam   56   Lalitpur  9808667654
# 2   3  Nabin   78  Bhaktapur  9856554543

# %%
df.tail(3)
# Out:
#    Sn    Name  Age    Address       Phone
# 3   4   Sabin   54       Bara  9867554543
# 4   5  Nirman   12       Bara  9808556543
# 5   6  Sabina   56  Kathmandu  9808667654

# %%
df.iloc[1:4]
# Out:
#    Sn   Name  Age    Address       Phone
# 1   2  Shyam   56   Lalitpur  9808667654
# 2   3  Nabin   78  Bhaktapur  9856554543
# 3   4  Sabin   54       Bara  9867554543

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df.loc[2:5]
# Out:
#       Name  Age    Address       Phone
# Sn
# 2    Shyam   56   Lalitpur  9808667654
# 3    Nabin   78  Bhaktapur  9856554543
# 4    Sabin   54       Bara  9867554543
# 5   Nirman   12       Bara  9808556543

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name')
# df
df.loc["Shyam":"Sabin"]
# Out:
#        Sn  Age    Address       Phone
# Name
# Shyam   2   56   Lalitpur  9808667654
# Nabin   3   78  Bhaktapur  9856554543
# Sabin   4   54       Bara  9867554543

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[df['Address'] == "Kathmandu"]
# Out:
#       Name  Age    Address       Phone
# Sn
# 1      Ram   34  Kathmandu  9898667654
# 6   Sabina   56  Kathmandu  9808667654

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
data = df[df['Address'] == "Kathmandu"]
data.to_csv('Newdata.csv')

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[(df['Address'] == "Kathmandu") & (df['Age']>40)]
# Out:
#       Name  Age    Address       Phone
# Sn
# 6   Sabina   56  Kathmandu  9808667654

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[(df['Address'] == "Kathmandu") | (df['Age']>40)]
# Out:
#       Name  Age    Address       Phone
# Sn
# 1      Ram   34  Kathmandu  9898667654
# 2    Shyam   56   Lalitpur  9808667654
# 3    Nabin   78  Bhaktapur  9856554543
# 4    Sabin   54       Bara  9867554543
# 6   Sabina   56  Kathmandu  9808667654

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
list(df['Age'])
# Out:
# [34, 56, 78, 54, 12, 56]

# %%
import pandas as pd

d = {"Name":["ram","Shya"],
    "Age":[23,54],
    "Add":["Kathmandu",None]}
data = pd.DataFrame(d)
data
# Out:
#    Name  Age        Add
# 0   ram   23  Kathmandu
# 1  Shya   54       None
